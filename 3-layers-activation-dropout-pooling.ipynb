# %% [markdown]
# # Layers
#
# ## 1. Activation Layers
#
# We use `activation layers` check the Y value produced by a neuron and decide whether outside connections should consider this neuron as “fired” or not. Or rather let’s say — “activated” or not.
#
# - https://keras.io/activations/
#
# **Issues with linear activation layers**

# %% [markdown]
# ## 1.1.  Sigmoid functions
#
# Sigmoid functions are one of the most widely used activation functions today. Output will be always in range (0,1) leaving out the problem of **exploding gradients**
#
# `keras.activations.sigmoid(x)`
#
# <img src="https://www.researchgate.net/profile/Tali_Leibovich-Raveh/publication/325868989/figure/fig2/AS:639475206074368@1529474178211/A-Basic-sigmoid-function-with-two-parameters-c1-and-c2-as-commonly-used-for-subitizing.png" width="350"/>

# %% [markdown]
# ## 1.2 Tanh
#
#
# <img src="https://miro.medium.com/max/1288/1*WNTLbBRWFiHPoXvyZ6s9eg.png" width="300"/>
#
# ## 1.3 ReLu
#
# https://machinelearningmastery.com/rectified-linear-activation-function-for-deep-learning-neural-networks/

# %%
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Activation
import numpy as np

activations = ["relu","sigmoid","tanh"]

y = dict()
x = np.expand_dims(np.linspace(-10,10,100),0)

for activation in activations:
    model = Sequential()
    model.add(Activation(activation))
    y[activation] = model.predict(x)


for name,act in y.items():
    plt.figure()
    plt.plot(act[0]) 
    plt.legend([name])

# %% [markdown]
# # 2. Pooling
#
# <img src="https://i.stack.imgur.com/6WbWu.png" width="400"/>

# %% [markdown]
# # 3. Dropout
#
# <img src="https://cdn-images-1.medium.com/max/1000/1*zwucz12TmYEaca5OcaPvbA.png" width="480"/>

# %% [markdown]
# # 3. Neural Networks issues
#
# https://towardsdatascience.com/neural-networks-problems-solutions-fa86e2da3b22

# %% [markdown]
# Refs
#
# - https://medium.com/the-theory-of-everything/understanding-activation-functions-in-neural-networks-9491262884e0
